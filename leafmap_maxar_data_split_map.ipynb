# %%
# Visualizing Maxar Open Data using leafmap
# case:India Floods, October, 2023 

import leafmap
import geopandas as gpd
import pandas as pd

# %%
# Retrieving all collections from the Maxar Open Data STAC catalog
leafmap.maxar_collections()
# Out:
# ['BayofBengal-Cyclone-Mocha-May-23',
#  'Emilia-Romagna-Italy-flooding-may23',
#  'Gambia-flooding-8-11-2022',
#  'Hurricane-Fiona-9-19-2022',
#  'Hurricane-Ian-9-26-2022',
#  'Hurricane-Idalia-Florida-Aug23',
#  'India-Floods-Oct-2023',
#  'Indonesia-Earthquake22',
#  'Kahramanmaras-turkey-earthquake-23',
#  'Kalehe-DRC-Flooding-5-8-23',
#  'Libya-Floods-Sept-2023',
#  'Marshall-Fire-21-Update',
#  'Maui-Hawaii-fires-Aug-23',
#  'McDougallCreekWildfire-BC-Canada-Aug-23',
#  'Morocco-Earthquake-Sept-2023',
#  'NWT-Canada-Aug-23',
#  'New-Zealand-Flooding22',
#  'New-Zealand-Flooding23',
#  'Sudan-flooding-8-22-2022',
#  'afghanistan-earthquake22',
#  'cyclone-emnati22',
#  'ghana-explosion22',
#  'kentucky-flooding-7-29-2022',
#  'pakistan-flooding22',
#  'shovi-georgia-landslide-8Aug23',
#  'southafrica-flooding22',
#  'tonga-volcano21',
#  'volcano-indonesia21',
#  'yellowstone-flooding22']

# %%
# Selecting India Floods collection id ("India-Floods-Oct-2023")
# Getting the footprints (geojson, tsv) of the event from the Maxar Open Data GitHub repo
# https://github.com/opengeos/maxar-open-data

collection = 'India-Floods-Oct-2023'
url = leafmap.maxar_collection_url(collection, dtype='geojson')
url
# Out:
# 'https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/India-Floods-Oct-2023.geojson'

# %%
# Checking the amount of images for the event
gdf = gpd.read_file(url)
print(f'Total number of images: {len(gdf)}')
gdf.head()
# Out:
# Total number of images: 51
#                    datetime platform   gsd ard_metadata_version
# 0 2022-03-07 04:53:47+00:00     WV02  0.56                0.0.1  \
# 1 2022-03-07 04:53:47+00:00     WV02  0.56                0.0.1
# 2 2022-03-07 04:53:48+00:00     WV02  0.56                0.0.1
# 3 2022-03-07 04:53:48+00:00     WV02  0.56                0.0.1
# 4 2022-03-07 04:53:48+00:00     WV02  0.57                0.0.1
#
#          catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth
# 0  10300100CE36CE00        45  120220031201            26.0          16.6  \
# 1  10300100CE36CE00        45  120220031210            26.0          16.0
# 2  10300100CE36CE00        45  120220031203            26.2          16.4
# 3  10300100CE36CE00        45  120220031212            26.1          15.9
# 4  10300100CE36CE00        45  120220031221            26.3          16.2
#
#    view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg
# 0                  60.5             145.2                51.2      32645  \
# 1                  60.6             145.2                51.2      32645
# 2                  60.4             145.2                51.2      32645
# 3                  60.5             145.2                51.2      32645
# 4                  60.3             145.2                51.2      32645
#
#                grid:code                                          proj:bbox
# 0  MXRA-Z45-120220031201  625296.8635054945,3094843.75,630156.25,3096239...  \
# 1  MXRA-Z45-120220031210  629843.75,3094843.75,633024.0847732465,3096270...
# 2  MXRA-Z45-120220031203  625307.5956898255,3089843.75,630156.25,3095156.25
# 3  MXRA-Z45-120220031212  629843.75,3089843.75,633050.5890839597,3095156.25
# 4  MXRA-Z45-120220031221  625359.7006774588,3086232.4385818127,630156.25...
#
#    tile:data_area  tile:clouds_area  tile:clouds_percent
# 0             6.6               0.0                    0  \
# 1             4.4               0.0                    0
# 2            25.6               0.0                    0
# 3            16.9               0.0                    0
# 4            18.6               0.0                    0
#
#                                               visual
# 0  https://maxar-opendata.s3.amazonaws.com/events...  \
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                             geometry
# 0  POLYGON ((88.32336 27.97234, 88.27411 27.97281...
# 1  POLYGON ((88.32019 27.97237, 88.32034 27.98493...
# 2  POLYGON ((88.32340 27.97516, 88.32281 27.92722...
# 3  POLYGON ((88.31964 27.92725, 88.32022 27.97519...
# 4  POLYGON ((88.32285 27.93004, 88.32242 27.89509...

# %%
# Selecting the images captured before the event (4th October 2023)
pre_gdf = leafmap.maxar_search(collection, end_date='2023-10-04')
print(f'Total number of pre-event images: {len(pre_gdf)}')
pre_gdf.head()
# Out:
# Total number of pre-event images: 42
#                    datetime platform   gsd ard_metadata_version
# 0 2022-03-07 04:53:47+00:00     WV02  0.56                0.0.1  \
# 1 2022-03-07 04:53:47+00:00     WV02  0.56                0.0.1
# 2 2022-03-07 04:53:48+00:00     WV02  0.56                0.0.1
# 3 2022-03-07 04:53:48+00:00     WV02  0.56                0.0.1
# 4 2022-03-07 04:53:48+00:00     WV02  0.57                0.0.1
#
#          catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth
# 0  10300100CE36CE00        45  120220031201            26.0          16.6  \
# 1  10300100CE36CE00        45  120220031210            26.0          16.0
# 2  10300100CE36CE00        45  120220031203            26.2          16.4
# 3  10300100CE36CE00        45  120220031212            26.1          15.9
# 4  10300100CE36CE00        45  120220031221            26.3          16.2
#
#    view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg
# 0                  60.5             145.2                51.2      32645  \
# 1                  60.6             145.2                51.2      32645
# 2                  60.4             145.2                51.2      32645
# 3                  60.5             145.2                51.2      32645
# 4                  60.3             145.2                51.2      32645
#
#                grid:code                                          proj:bbox
# 0  MXRA-Z45-120220031201  625296.8635054945,3094843.75,630156.25,3096239...  \
# 1  MXRA-Z45-120220031210  629843.75,3094843.75,633024.0847732465,3096270...
# 2  MXRA-Z45-120220031203  625307.5956898255,3089843.75,630156.25,3095156.25
# 3  MXRA-Z45-120220031212  629843.75,3089843.75,633050.5890839597,3095156.25
# 4  MXRA-Z45-120220031221  625359.7006774588,3086232.4385818127,630156.25...
#
#    tile:data_area  tile:clouds_area  tile:clouds_percent
# 0             6.6               0.0                    0  \
# 1             4.4               0.0                    0
# 2            25.6               0.0                    0
# 3            16.9               0.0                    0
# 4            18.6               0.0                    0
#
#                                               visual
# 0  https://maxar-opendata.s3.amazonaws.com/events...  \
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                             geometry
# 0  POLYGON ((88.32336 27.97234, 88.27411 27.97281...
# 1  POLYGON ((88.32019 27.97237, 88.32034 27.98493...
# 2  POLYGON ((88.32340 27.97516, 88.32281 27.92722...
# 3  POLYGON ((88.31964 27.92725, 88.32022 27.97519...
# 4  POLYGON ((88.32285 27.93004, 88.32242 27.89509...

# %%
# Selectin images captured after the event
post_gdf = leafmap.maxar_search(collection, start_date='2023-10-04')
print(f'Total number of post-event images: {len(post_gdf)}')
post_gdf.head()
# Out:
# Total number of post-event images: 9
#                     datetime platform   gsd ard_metadata_version
# 42 2023-10-06 05:04:39+00:00     GE01  0.49                0.0.1  \
# 43 2023-10-06 05:04:39+00:00     GE01  0.49                0.0.1
# 44 2023-10-06 05:04:39+00:00     GE01  0.49                0.0.1
# 45 2023-10-06 05:04:40+00:00     GE01  0.49                0.0.1
# 46 2023-10-06 05:04:40+00:00     GE01  0.49                0.0.1
#
#           catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth
# 42  1050010036A0EC00        45  120220030313            26.1         261.6  \
# 43  1050010036A0EC00        45  120220030331            26.0         262.5
# 44  1050010036A0EC00        45  120220030333            26.0         263.3
# 45  1050010036A0EC00        45  120220030312            25.9         260.4
# 46  1050010036A0EC00        45  120220030323            25.7         261.5
#
#     view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg
# 42                  60.9             157.6                55.0      32645  \
# 43                  61.0             157.6                55.0      32645
# 44                  61.0             157.6                55.0      32645
# 45                  61.1             157.6                55.0      32645
# 46                  61.3             157.6                55.0      32645
#
#                 grid:code                                          proj:bbox
# 42  MXRA-Z45-120220030313  614843.75,3089843.75,617668.6296208797,3091672...  \
# 43  MXRA-Z45-120220030331  614843.75,3084843.75,617717.4718004398,3090156.25
# 44  MXRA-Z45-120220030333  614843.75,3081698.7778129643,617747.929473526,...
# 45  MXRA-Z45-120220030312   609843.75,3089843.75,615156.25,3091649.212635094
# 46  MXRA-Z45-120220030323  608496.9881654698,3081640.641251588,610156.25,...
#
#     tile:data_area  tile:clouds_area  tile:clouds_percent
# 42             5.1               0.0                    0  \
# 43            15.1               0.0                    0
# 44             9.9               0.0                    0
# 45             9.4               0.0                    0
# 46             5.4               0.0                    0
#
#                                                visual
# 42  https://maxar-opendata.s3.amazonaws.com/events...  \
# 43  https://maxar-opendata.s3.amazonaws.com/events...
# 44  https://maxar-opendata.s3.amazonaws.com/events...
# 45  https://maxar-opendata.s3.amazonaws.com/events...
# 46  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              geometry
# 42  POLYGON ((88.16722 27.92862, 88.16739 27.94489...
# 43  POLYGON ((88.16673 27.88350, 88.16725 27.93145...
# 44  POLYGON ((88.16676 27.88632, 88.19592 27.88606...
# 45  POLYGON ((88.17039 27.92860, 88.11641 27.92905...
# 46  POLYGON ((88.11915 27.88671, 88.11882 27.85511...

# %%
# Visualizing the pre-event and post-event image footprints on the map to select are of interest to present on the split map
# Pre-events: blue colour, post-events: red colour

m = leafmap.Map(center=(27.4978, 88.5347), zoom=8)
post_style = {'color': 'red', 'fillColor': 'red', 'opacity': 1, 'fillOpacity': 0.5}
m.add_gdf(pre_gdf, layer_name='Pre-event', info_mode='on_click')
m.add_gdf(post_gdf, layer_name='Post-event', info_mode='on_click', style=post_style)
m
# Out:
# Map(center=[27.4978, 88.5347], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zo…

# %%
# Using the draw tools to select a region of interest (ROI) and get the bounding box coordinates
bbox = m.user_roi_bounds()
if bbox is None:
    bbox = [88.0997,27.8516 ,88.2019, 27.9471]

# %%
# Searching the Maxar Open Data catalog for images within the ROI before the event
pre_event = leafmap.maxar_search(collection, bbox=bbox, end_date='2023-10-04')
pre_event.head()
# Out:
#                     datetime platform   gsd ard_metadata_version
# 33 2023-02-07 04:40:45+00:00     WV02  0.58                0.0.1  \
# 34 2023-02-07 04:40:45+00:00     WV02  0.58                0.0.1
# 35 2023-02-07 04:40:45+00:00     WV02  0.58                0.0.1
# 36 2023-02-07 04:40:46+00:00     WV02  0.58                0.0.1
# 37 2023-02-07 04:40:46+00:00     WV02  0.58                0.0.1
#
#           catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth
# 33  10300100E34B4D00        45  120220030303            28.1          92.2  \
# 34  10300100E34B4D00        45  120220030312            28.0          92.2
# 35  10300100E34B4D00        45  120220030313            27.7          92.2
# 36  10300100E34B4D00        45  120220030321            28.1          91.9
# 37  10300100E34B4D00        45  120220030323            28.0          91.7
#
#     view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg
# 33                  58.1             147.4                40.5      32645  \
# 34                  58.3             147.4                40.5      32645
# 35                  58.6             147.4                40.5      32645
# 36                  58.2             147.4                40.5      32645
# 37                  58.2             147.4                40.5      32645
#
#                 grid:code                                          proj:bbox
# 33  MXRA-Z45-120220030303  608245.9743433739,3089843.75,610156.25,3091602...  \
# 34  MXRA-Z45-120220030312   609843.75,3089843.75,615156.25,3091649.212635094
# 35  MXRA-Z45-120220030313  614843.75,3089843.75,617668.6296208797,3091672...
# 36  MXRA-Z45-120220030321  608230.4609330465,3084843.75,610156.25,3090156.25
# 37  MXRA-Z45-120220030323  608501.8920898438,3081640.641251588,610156.25,...
#
#     tile:data_area  tile:clouds_area  tile:clouds_percent
# 33             3.1               0.0                    0  \
# 34             9.4               0.0                    0
# 35             5.1               0.0                    0
# 36             9.6               0.0                    0
# 37             5.2               0.0                    0
#
#                                                visual
# 33  https://maxar-opendata.s3.amazonaws.com/events...  \
# 34  https://maxar-opendata.s3.amazonaws.com/events...
# 35  https://maxar-opendata.s3.amazonaws.com/events...
# 36  https://maxar-opendata.s3.amazonaws.com/events...
# 37  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              geometry
# 33  POLYGON ((88.11958 27.92902, 88.10017 27.92918...
# 34  POLYGON ((88.17039 27.92860, 88.11641 27.92905...
# 35  POLYGON ((88.16722 27.92862, 88.16739 27.94489...
# 36  POLYGON ((88.11961 27.93184, 88.11912 27.88389...
# 37  POLYGON ((88.11915 27.88671, 88.11882 27.85511...

# %%
# Searching the Maxar Open Data catalog for images within the ROI after the event
post_event = leafmap.maxar_search(collection, bbox=bbox, start_date='2023-10-04')
post_event.head()
# Out:
#                     datetime platform   gsd ard_metadata_version
# 42 2023-10-06 05:04:39+00:00     GE01  0.49                0.0.1  \
# 43 2023-10-06 05:04:39+00:00     GE01  0.49                0.0.1
# 44 2023-10-06 05:04:39+00:00     GE01  0.49                0.0.1
# 45 2023-10-06 05:04:40+00:00     GE01  0.49                0.0.1
# 46 2023-10-06 05:04:40+00:00     GE01  0.49                0.0.1
#
#           catalog_id  utm_zone       quadkey  view:off_nadir  view:azimuth
# 42  1050010036A0EC00        45  120220030313            26.1         261.6  \
# 43  1050010036A0EC00        45  120220030331            26.0         262.5
# 44  1050010036A0EC00        45  120220030333            26.0         263.3
# 45  1050010036A0EC00        45  120220030312            25.9         260.4
# 46  1050010036A0EC00        45  120220030323            25.7         261.5
#
#     view:incidence_angle  view:sun_azimuth  view:sun_elevation  proj:epsg
# 42                  60.9             157.6                55.0      32645  \
# 43                  61.0             157.6                55.0      32645
# 44                  61.0             157.6                55.0      32645
# 45                  61.1             157.6                55.0      32645
# 46                  61.3             157.6                55.0      32645
#
#                 grid:code                                          proj:bbox
# 42  MXRA-Z45-120220030313  614843.75,3089843.75,617668.6296208797,3091672...  \
# 43  MXRA-Z45-120220030331  614843.75,3084843.75,617717.4718004398,3090156.25
# 44  MXRA-Z45-120220030333  614843.75,3081698.7778129643,617747.929473526,...
# 45  MXRA-Z45-120220030312   609843.75,3089843.75,615156.25,3091649.212635094
# 46  MXRA-Z45-120220030323  608496.9881654698,3081640.641251588,610156.25,...
#
#     tile:data_area  tile:clouds_area  tile:clouds_percent
# 42             5.1               0.0                    0  \
# 43            15.1               0.0                    0
# 44             9.9               0.0                    0
# 45             9.4               0.0                    0
# 46             5.4               0.0                    0
#
#                                                visual
# 42  https://maxar-opendata.s3.amazonaws.com/events...  \
# 43  https://maxar-opendata.s3.amazonaws.com/events...
# 44  https://maxar-opendata.s3.amazonaws.com/events...
# 45  https://maxar-opendata.s3.amazonaws.com/events...
# 46  https://maxar-opendata.s3.amazonaws.com/events...
#
#                                              geometry
# 42  POLYGON ((88.16722 27.92862, 88.16739 27.94489...
# 43  POLYGON ((88.16673 27.88350, 88.16725 27.93145...
# 44  POLYGON ((88.16676 27.88632, 88.19592 27.88606...
# 45  POLYGON ((88.17039 27.92860, 88.11641 27.92905...
# 46  POLYGON ((88.11915 27.88671, 88.11882 27.85511...

# %%
# Getting the catalog id of the pre-event tile and post-event tile, which contain several images
pre_tile = pre_event['catalog_id'].values[0]
post_tile = post_event['catalog_id'].values[0]

print(f"pre_tile: {pre_tile}\npost_tile: {post_tile}")
# Out:
# pre_tile: 10300100E34B4D00
# post_tile: 1050010036A0EC00

# %%
# Getting the MosaicJSON for the pre-event and post-event tile
pre_stac = leafmap.maxar_tile_url(collection, pre_tile, dtype='json')
post_stac = leafmap.maxar_tile_url(collection, post_tile, dtype='json')
print(f"{pre_stac}\n{post_stac}")
# Out:
# https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/India-Floods-Oct-2023/10300100E34B4D00.json
# https://raw.githubusercontent.com/giswqs/maxar-open-data/master/datasets/India-Floods-Oct-2023/1050010036A0EC00.json

# %%
# Creating a split map to compare the pre-event and post-event images
import leafmap.foliumap as leafmap

event_map = leafmap.Map(draw_control=False)

event_map.split_map(
    left_layer=pre_stac,
    right_layer=post_stac,
    left_label='Pre-event',
    right_label='Post-event',
    center=[27.4978, 88.5347],
    zoom=10,
)
event_map
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24cfb4e3727ab8e0ff71654511d06ccd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/digidem/leaflet-side-by-side@gh-pages/leaflet-side-by-side.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24cfb4e3727ab8e0ff71654511d06ccd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24cfb4e3727ab8e0ff71654511d06ccd = L.map(
#                 &quot;map_24cfb4e3727ab8e0ff71654511d06ccd&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawControl: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_24cfb4e3727ab8e0ff71654511d06ccd);
#
#
#
#
#
#             var tile_layer_3c71284f4836a5cca481a77569fb9487 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24cfb4e3727ab8e0ff71654511d06ccd);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_24cfb4e3727ab8e0ff71654511d06ccd);
#
#
#             var measure_control_fbf69b8f4ea8fd45736295a45d3dd81f = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_24cfb4e3727ab8e0ff71654511d06ccd.addControl(measure_control_fbf69b8f4ea8fd45736295a45d3dd81f);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_24cfb4e3727ab8e0ff71654511d06ccd.setView(e.geocode.center, 11);
#             }).addTo(map_24cfb4e3727ab8e0ff71654511d06ccd);
#
#
#
#             map_24cfb4e3727ab8e0ff71654511d06ccd.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_6f5a6d4ff6014e68af684ff8d011b6de = L.tileLayer(
#                 &quot;https://titiler.xyz/mosaicjson/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?max_zoom=100\u0026max_native_zoom=100\u0026layer_name=Left+Layer\u0026url=https%3A%2F%2Fraw.githubusercontent.com%2Fgiswqs%2Fmaxar-open-data%2Fmaster%2Fdatasets%2FIndia-Floods-Oct-2023%2F10300100E34B4D00.json&quot;,
#                 {&quot;attribution&quot;: &quot; &quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24cfb4e3727ab8e0ff71654511d06ccd);
#
#
#             var tile_layer_70f6df53209527e8467a3f64436fca38 = L.tileLayer(
#                 &quot;https://titiler.xyz/mosaicjson/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?max_zoom=100\u0026max_native_zoom=100\u0026layer_name=Left+Layer\u0026url=https%3A%2F%2Fraw.githubusercontent.com%2Fgiswqs%2Fmaxar-open-data%2Fmaster%2Fdatasets%2FIndia-Floods-Oct-2023%2F1050010036A0EC00.json&quot;,
#                 {&quot;attribution&quot;: &quot; &quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24cfb4e3727ab8e0ff71654511d06ccd);
#
#
#             var side_by_side_layers_29b3a247ad3ed37d9f99599005a03e72 = L.control.sideBySide(
#                 tile_layer_6f5a6d4ff6014e68af684ff8d011b6de, tile_layer_70f6df53209527e8467a3f64436fca38
#             ).addTo(map_24cfb4e3727ab8e0ff71654511d06ccd);
#
#
#         L.Control.CustomControl = L.Control
